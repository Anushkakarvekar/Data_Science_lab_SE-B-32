# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkakarvekar/Data_Science_lab_SE-B-32/blob/main/positiveornotdsl1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
else:
    print("The number is Not Positive")
# Out:
# Enter a number: 10
# The number is Positive
