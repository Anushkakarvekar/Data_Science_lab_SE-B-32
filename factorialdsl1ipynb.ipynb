# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkakarvekar/Data_Science_lab_SE-B-32/blob/main/factorialdsl1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
fact = 1

for i in range(1, num + 1):
    fact = fact * i

print("Factorial of", num, "is", fact)
# Out:
# Enter a number: 5
# Factorial of 5 is 120
