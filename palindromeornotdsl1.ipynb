# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkakarvekar/Data_Science_lab_SE-B-32/blob/main/palindromeornotdsl1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = input("Enter a number: ")

if num == num[::-1]:
    print("The number is Palindrome")
else:
    print("The number is Not a Palindrome")
# Out:
# Enter a number: 9
# The number is Palindrome
